# %% [markdown]
# <a href="https://colab.research.google.com/github/SOURAVcse9/Learn_Python/blob/basic_of_python/learn__python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
print (3+3)
# Out:
# hello world
# 6
# '\nThis is a comment\nwritten in\nmore than just one line\n'

# %%
x=5
name="Sourav"
print(name,x,"years old")
# Out:
# Sourav 5 years old

# %%
#Python Variable
# Define variables
x1 = "Hello World"
x2 = 20
x3 = 20.5
x4 = 1j
x5 = ["apple", "banana", "cherry"]
x6 = ("apple", "banana", "cherry")
x7 = range(6)
x8 = {"name": "John", "age": 36}
x9 = {"apple", "banana", "cherry"}
x10 = frozenset({"apple", "banana", "cherry"})
x11 = True
x12 = b"Hello"
x13 = bytearray(5)
x14 = memoryview(bytes(5))
x15 = None

# Print types
print("x1:", type(x1))
print("x2:", type(x2))
print("x3:", type(x3))
print("x4:", type(x4))
print("x5:", type(x5))
print("x6:", type(x6))
print("x7:", type(x7))
print("x8:", type(x8))
print("x9:", type(x9))
print("x10:", type(x10))
print("x11:", type(x11))
print("x12:", type(x12))
print("x13:", type(x13))
print("x14:", type(x14))
print("x15:", type(x15))
# Out:
# x1: <class 'str'>
# x2: <class 'int'>
# x3: <class 'float'>
# x4: <class 'complex'>
# x5: <class 'list'>
# x6: <class 'tuple'>
# x7: <class 'range'>
# x8: <class 'dict'>
# x9: <class 'set'>
# x10: <class 'frozenset'>
# x11: <class 'bool'>
# x12: <class 'bytes'>
# x13: <class 'bytearray'>
# x14: <class 'memoryview'>
# x15: <class 'NoneType'>

# %%
x=5
y=6.55
p=float(x)
q=int(y)
print(p)
print(q)
# Out:
# 5.0
# 6

# %%
name="sourav"
for x in name:
  print(x)
# Out:
# s
# o
# u
# r
# a
# v

# %%
name="Sourav Debnath"
x=name.upper()
y=name.lower()
z=name.replace("Debnath","Gita")
print(x)
print(y)
print(z)
# Out:
# SOURAV DEBNATH
# sourav debnath
# Sourav Gita

# %%
print(10>0)
print (0>10)
print ("a"=="b")
print (10==20)
# Out:
# True
# False
# False
# False

# %%
x = 15
y = 4

print("addition:",x + y)
print("subtraction:",x - y)
print("multiplication:",x * y)
print("division:",x / y)
print("modulation:",x % y)
print("exponention:",x ** y)
print("floor division:" ,x // y)
# Out:
# addition: 19
# subtraction: 11
# multiplication: 60
# division: 3.75
# modulation: 3
# exponention: 50625
# floor division: 3

# %% [markdown]
# **Python List**
#
# Lists are used to store multiple items in a single variable.

# %%
thislist = ["apple", "banana", "cherry"]
name =["utso", "neloy",1,2,3,"dipta"]
print(thislist)
print(name)
print(len(name))
print(type(name))
# Out:
# ['apple', 'banana', 'cherry']
# ['utso', 'neloy', 1, 2, 3, 'dipta']
# 6
# <class 'list'>

# %% [markdown]
# **Python Collections (Arrays)**
#
# There are four collection data types in the Python programming language:
#
# **List** is a collection which is ordered and changeable. Allows duplicate members.
#
# **Tuple** is a collection which is ordered and unchangeable. Allows duplicate members.
#
# **Set** is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
#
# **Dictionary**
#  is a collection which is ordered** and changeable. No duplicate members.

# %%
#append a item
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
#remove an item
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)

# %%
#clear the list
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %% [markdown]
# ![Screenshot 2026-04-11 135340.png](data:image/png;base64,...)
