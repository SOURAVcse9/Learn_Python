# %% [markdown]
# <a href="https://colab.research.google.com/github/SOURAVcse9/Learn_Python/blob/Machine-Learning/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installation of Matplotlib
# pip install matplotlib\

# %%
Installation of Matplotlib
pip install matplotlib
